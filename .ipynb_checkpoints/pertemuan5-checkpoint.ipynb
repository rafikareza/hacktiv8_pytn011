# %%
import numpy as np
import pandas as pd # untuk membaca, edit, dan bikin juga data yang tipenya 2 dimensi
#seperti excel, csv, tabel, database sql data
#dll

# %%
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Dokumen/HACKTIV8/data/nbaallelo.csv')

# %%
df.shape #
# Out:
# (126314, 23)

# %%
len(df)
# Out:
# 126314

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
#   opp_elo_i opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...      60.31     GSW
# 126310         102            1     GSW   Warriors  ...      68.01     CLE
# 126311         101            1     CLE  Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE  Cavaliers  ...      59.29     GSW
# 126313         103            1     GSW   Warriors  ...      68.52     CLE
#
#          opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.precision",2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
# teknik eksplorasi dataframe, contohnya 
# value_counts() menghitung jumlah data yang unik 
df["team_id"].value_counts() # no. ktp
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# INJ      60
# DTF      60
# PIT      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts() # nama orang nya
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df['fran_id'] == 'Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL','date_game'].value_counts()
# Out:
# 11/28/1948    1
# 12/25/1957    1
# 12/5/1951     1
# 12/17/1955    1
# 1/20/1951     1
#              ..
# 2/24/1951     1
# 4/5/1953      1
# 3/13/1957     1
# 12/19/1952    1
# 4/5/1950      1
# Name: date_game, Length: 946, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL','date_game'].max()
# Out:
# '4/9/1959'

# %%
df.loc[df['team_id'] == 'MNL','date_game'].min()
# Out:
# '1/1/1949'

# %%
# kita bisa pakai bantuan agg (aggregate) untuk gabungin bbrp informasi jadi satu
df.loc[df['team_id'] == 'MNL','date_game'].agg(('min','max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df.loc[df['team_id'] == 'MNL','pts'].sum()
# Out:
# 88229

# %%
df.loc[df['team_id'] == 'MNL', 'pts'].agg(('min','max','sum'))
# Out:
# min       18
# max      139
# sum    88229
# Name: pts, dtype: int64

# %% [markdown]
# ## Series in Pandas

# %%
revenues = pd.Series(
    [3500,4578,9832]
)
revenues
# Out:
# 0    3500
# 1    4578
# 2    9832
# dtype: int64

# %%
city_revenues = pd.Series(
    {"Jakarta": 3500, "Bali": 4578, "Riau":9832}
)
city_revenues
# Out:
# Jakarta    3500
# Bali       4578
# Riau       9832
# dtype: int64

# %%
city_revenues.keys() # melihat index
# Out:
# Index(['Jakarta', 'Bali', 'Riau'], dtype='object')

# %%
city_revenues.values # melihat value
# Out:
# array([3500, 4578, 9832], dtype=int64)

# %% [markdown]
# ## kembali ke DataFrame

# %%
city_revenues
# Out:
# Jakarta    3500
# Bali       4578
# Riau       9832
# dtype: int64

# %%
city_employee_count = pd.Series(
    {"Jakarta": 100, "Bali": 50, "Palembang":22}
)
city_employee_count
# Out:
# Jakarta      100
# Bali          50
# Palembang     22
# dtype: int64

# %%
city_data = pd.DataFrame(
    {"revenue": city_revenues, "employee": city_employee_count}
)
city_data #bikin data frame yang punya 2 kolom
# Out:
#            revenue  employee
# Bali        4578.0      50.0
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data.index
# Out:
# Index(['Bali', 'Jakarta', 'Palembang', 'Riau'], dtype='object')

# %%
city_data.values
# Out:
# array([[4578.,   50.],
#        [3500.,  100.],
#        [  nan,   22.],
#        [9832.,   nan]])

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Bali to Riau
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   revenue   3 non-null      float64
#  1   employee  3 non-null      float64
# dtypes: float64(2)
# memory usage: 96.0+ bytes

# %%
city_data.describe()
# Out:
#        revenue  employee
# count     3.00      3.00
# mean   5970.00     57.33
# std    3387.74     39.51
# min    3500.00     22.00
# 25%    4039.00     36.00
# 50%    4578.00     50.00
# 75%    7205.00     75.00
# max    9832.00    100.00

# %%
city_data.axes # axes kasih lihat rows (index isinya apa saja) dan columns (kolomnya isinya apa saja)
# Out:
# [Index(['Bali', 'Jakarta', 'Palembang', 'Riau'], dtype='object'),
#  Index(['revenue', 'employee'], dtype='object')]

# %%
city_data.shape
# Out:
# (4, 2)

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee'], dtype='object')

# %%
"Jakarta" in city_data
# Out:
# False

# %%
"Jakarta" in city_data.index
# Out:
# True

# %% [markdown]
# ## Eksplorasi data NBA untuk axes

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %% [markdown]
# ### loc vs iloc

# %%
city_revenues
# Out:
# Jakarta    3500
# Bali       4578
# Riau       9832
# dtype: int64

# %%
city_revenues["Bali"]
# Out:
# 4578

# %%
city_revenues[1]
# Out:
# 4578

# %%
city_revenues["Bali" : ]
# Out:
# Bali    4578
# Riau    9832
# dtype: int64

# %%
city_revenues[1:]
# Out:
# Bali    4578
# Riau    9832
# dtype: int64

# %%
city_revenues[-1]
# Out:
# 9832

# %%
city_data
# Out:
#            revenue  employee
# Bali        4578.0      50.0
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data.loc['Bali']
# Out:
# revenue     4578.0
# employee      50.0
# Name: Bali, dtype: float64

# %%
city_data.loc['Bali' :]
# Out:
#            revenue  employee
# Bali        4578.0      50.0
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data.loc['Jakarta' :]
# Out:
#            revenue  employee
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data.iloc[1:]
# Out:
#            revenue  employee
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data.iloc[-1]
# Out:
# revenue     9832.0
# employee       NaN
# Name: Riau, dtype: float64

# %%
city_data.loc[city_data['revenue'] > 3500]
# Out:
#       revenue  employee
# Bali   4578.0      50.0
# Riau   9832.0       NaN

# %% [markdown]
# ## Quering DataFrame

# %%
df.loc[df['year_id']> 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.loc[(df['year_id'] > 2010) & (df['team_id'] == 'BOS')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113663      56832  201010270CLE   NBA        1     2011  10/27/2010
# 113693      56847  201010290BOS   NBA        0     2011  10/29/2010
# 113750      56876  201011020DET   NBA        1     2011   11/2/2010
# 113763      56882  201011030BOS   NBA        0     2011   11/3/2010
# ...           ...           ...   ...      ...      ...         ...
# 126141      63071  201504150MIL   NBA        1     2015   4/15/2015
# 126162      63082  201504190CLE   NBA        1     2015   4/19/2015
# 126173      63087  201504210CLE   NBA        1     2015   4/21/2015
# 126185      63093  201504230BOS   NBA        0     2015   4/23/2015
# 126205      63103  201504260BOS   NBA        0     2015   4/26/2015
#
#         seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 113657           1            0     BOS  Celtics  ...      53.75     MIA
# ...

# %%
df.loc[df['year_id'] > 2010 & (df['team_id'] == 'BOS'), ['game_result', 'pts']]
# Out:
#        game_result  pts
# 0                L   66
# 1                W   68
# 2                W   63
# 3                L   47
# 4                L   33
# ...            ...  ...
# 126309           L   82
# 126310           W  104
# 126311           L   91
# 126312           L   97
# 126313           W  105
#
# [126314 rows x 2 columns]

# %%
city_data.loc[city_data['revenue'].notnull()]
# Out:
#          revenue  employee
# Bali      4578.0      50.0
# Jakarta   3500.0     100.0
# Riau      9832.0       NaN

# %%
'fika'
# Out:
# 'fika'

# %%
df.loc[df['notes'].notnull()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.loc[df['fran_id'].str.startswith('B')] # mengambil tim NBA yang namanya dimulai dari 'B'
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9               5  194611020STB   NBA        0     1947   11/2/1946
# 16              9  194611050DTF   NBA        1     1947   11/5/1946
# 22             12  194611070STB   NBA        0     1947   11/7/1946
# 32             17  194611090STB   NBA        0     1947   11/9/1946
# 47             24  194611140STB   NBA        0     1947  11/14/1946
# ...           ...           ...   ...      ...      ...         ...
# 126247      63124  201505060CLE   NBA        1     2015    5/6/2015
# 126250      63126  201505080CHI   NBA        0     2015    5/8/2015
# 126258      63130  201505100CHI   NBA        0     2015   5/10/2015
# 126267      63134  201505120CLE   NBA        1     2015   5/12/2015
# 126275      63138  201505140CHI   NBA        0     2015   5/14/2015
#
#         seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 9                1            0     STB  Bombers  ...      41.49     PIT
# ...

# %% [markdown]
# ## Grouping and Aggregating Data

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
#   opp_elo_i opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.groupby('fran_id')['pts'].sum() #dijumlahin semua ptsnya yang fran_idnya sama
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df.groupby(['fran_id', 'year_id'])['pts'].sum() # dijumlahin ptsnya tiap fran_id per tahunnya
# Out:
# fran_id    year_id
# Baltimore  1948       4491
#            1949       5272
#            1950       4973
#            1951       5414
#            1952       5377
#                       ...
# Wizards    2011       7977
#            2012       6180
#            2013       7644
#            2014       9248
#            2015       9091
# Name: pts, Length: 1487, dtype: int64

# %%
df.groupby(['fran_id'], sort=False)['pts'].sum() # sama kaya diatas cuman acak ga sesuai urutan abjad namanya
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df[df['fran_id']=='Lakers'].groupby(['team_id','year_id', 'game_result'])['game_id'].count()
# si Lakers ini di jumlah game idnya ada berapa pertahun tiap game resultnya
# Out:
# team_id  year_id  game_result
# LAL      1961     L              49
#                   W              42
#          1962     L              32
#                   W              61
#          1963     L              34
#                                  ..
# MNL      1958     W              19
#          1959     L              46
#                   W              39
#          1960     L              54
#                   W              30
# Name: game_id, Length: 134, dtype: int64

# %%
df[df['fran_id']=='Lakers'].groupby(['team_id','year_id', 'game_result'])['pts'].sum()
# Out:
# team_id  year_id  game_result
# LAL      1961     L              5328
#                   W              5089
#          1962     L              3526
#                   W              7486
#          1963     L              3668
#                                  ...
# MNL      1958     W              2129
#          1959     L              4781
#                   W              4223
#          1960     L              5588
#                   W              3394
# Name: pts, Length: 134, dtype: int64

# %% [markdown]
# ## Editing Columns in DataFrame

# %%
nba =df.copy()

# %%
#bikin kolom baru
nba['difference'] = nba['pts'] - nba['opp_pts']
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68    1300.00
# 1            0     NYK   Knicks  ...     TRH   Huskies       66    1300.00
# 2            0     CHS    Stags  ...     NYK    Knicks       47    1306.72
# 3            0     NYK   Knicks  ...     CHS     Stags       63    1300.00
# 4            0     DTF  Falcons  ...     WSC  Capitols       50    1300.00
#
#   opp_elo_n game_location  game_result  forecast  notes difference
# ...

# %%
#ubah nama kolom
nba_renamed = nba.rename(columns={"year_id":"year", "fran_id":"team_name"})
nba_renamed.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0  1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1  1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0  1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1  1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0  1947  11/2/1946           1
#
#    is_playoffs team_id team_name  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH   Huskies  ...     NYK    Knicks       68    1300.00
# 1            0     NYK    Knicks  ...     TRH   Huskies       66    1300.00
# 2            0     CHS     Stags  ...     NYK    Knicks       47    1306.72
# 3            0     NYK    Knicks  ...     CHS     Stags       63    1300.00
# 4            0     DTF   Falcons  ...     WSC  Capitols       50    1300.00
#
#   opp_elo_n game_location  game_result  forecast  notes difference
# ...

# %%
# drop kolom
nba_dropped = nba.drop("opp_elo_i", axis=1)
nba_dropped.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
#   opp_elo_n game_location  game_result  forecast notes difference
# ...

# %%
nba_dropped = nba.drop(["opp_elo_i", "opp_elo_n", "elo_i", "elo_n"], axis=1)
nba_dropped.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#   game_location game_result  forecast notes  difference
# ...

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#         'difference'],
#        dtype='object')]

# %%
nba_dropped.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'win_equiv',
#         'opp_id', 'opp_fran', 'opp_pts', 'game_location', 'game_result',
#         'forecast', 'notes', 'difference'],
#        dtype='object')]

# %% [markdown]
# ## Edit tipe data di kolom DF

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba['date_game'] = pd.to_datetime(nba['date_game'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba['game_location'].nunique()
# Out:
# 3

# %%
nba['game_location'].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba['game_location'] = pd.Categorical(nba['game_location'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba['game_location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %% [markdown]
# ## Hapus data yang "missing"

# %%
nba_clean = nba.dropna() # hapus rows yang ada value "missing"

# %%
nba_clean.shape
# Out:
# (5424, 24)

# %%
nba_clean.head()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 930         466  194801300BLB   NBA        1     1948 1948-01-30          28
# 931         466  194801300BLB   NBA        0     1948 1948-01-30          31
# 1084        543  194803230CHS   NBA        1     1948 1948-03-23          49
# 1085        543  194803230CHS   NBA        0     1948 1948-03-23          49
# 1088        545  194803250CHS   NBA        1     1948 1948-03-25          49
#
#       is_playoffs team_id    fran_id  ...  opp_id   opp_fran  opp_pts  \
# 930             0     WSC   Capitols  ...     BLB  Baltimore       95
# 931             0     BLB  Baltimore  ...     WSC   Capitols       71
# 1084            1     WSC   Capitols  ...     CHS      Stags       74
# 1085            1     CHS      Stags  ...     WSC   Capitols       70
# 1088            1     BLB  Baltimore  ...     CHS      Stags       72
#
#       opp_elo_i opp_elo_n game_location  game_result  forecast  \
# ...

# %%
nba_clean2 = nba.dropna(axis=1) # yang dihapus kolomnya
nba_clean2.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
# ...

# %%
nba_default_notes = nba.copy()

# nba_default_notes['notes'] = nba_default_notes['notes'].fillna(value="no notes") # cara 1
nba_default_notes['notes'].fillna(value="no notes", inplace=True) # cara 2nya

nba_default_notes.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68    1300.00
# 1            0     NYK   Knicks  ...     TRH   Huskies       66    1300.00
# 2            0     CHS    Stags  ...     NYK    Knicks       47    1306.72
# 3            0     NYK   Knicks  ...     CHS     Stags       63    1300.00
# 4            0     DTF  Falcons  ...     WSC  Capitols       50    1300.00
#
#   opp_elo_n game_location  game_result  forecast     notes difference
# ...

# %% [markdown]
# ## Mencari invalid data

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
nba[nba['pts'] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets  ...     VIR   Squires        2
#
#        opp_elo_i opp_elo_n game_location  game_result  forecast  \
# 26684    1484.19   1487.08             A            L      0.33
#
#                                 notes difference
# 26684  at Richmond VA; forfeit to VIR         -2
#
# [1 rows x 24 columns]

# %%
# contoh lain, cari yang menang tapi poinnya lebih sedikit
nba[(nba['pts'] < nba['opp_pts']) & (nba['game_result'] == 'W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes, difference]
# Index: []
#
# [0 rows x 24 columns]

# %%
nba[(nba['pts'] > nba['opp_pts']) & (nba['game_result'] == 'L')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes, difference]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ## COmbining Data

# %%
city_data
# Out:
#            revenue  employee
# Bali        4578.0      50.0
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN

# %%
city_data_2 = pd.DataFrame(
    {"revenue": [6547, 486], "employee": [14, 5]},
    index=["Kediri", "Sumba"]
)
city_data_2
# Out:
#         revenue  employee
# Kediri     6547        14
# Sumba       486         5

# %%
all_city = pd.concat([city_data, city_data_2])
all_city
# Out:
#            revenue  employee
# Bali        4578.0      50.0
# Jakarta     3500.0     100.0
# Palembang      NaN      22.0
# Riau        9832.0       NaN
# Kediri      6547.0      14.0
# Sumba        486.0       5.0

# %%
city_countries = pd.DataFrame({
    "country": ["Indonesia", "Japan", "Indonesia", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Jakarta", "Tokyo", "Bali", "Toronto", "Barcelona"]
)
city_countries
# Out:
#              country  capital
# Jakarta    Indonesia        1
# Tokyo          Japan        1
# Bali       Indonesia        0
# Toronto       Canada        0
# Barcelona      Spain        0

# %%
cities = pd.concat([all_city, city_countries], axis=1)
cities
# Out:
#            revenue  employee    country  capital
# Bali        4578.0      50.0  Indonesia      0.0
# Jakarta     3500.0     100.0  Indonesia      1.0
# Palembang      NaN      22.0        NaN      NaN
# Riau        9832.0       NaN        NaN      NaN
# Kediri      6547.0      14.0        NaN      NaN
# Sumba        486.0       5.0        NaN      NaN
# Tokyo          NaN       NaN      Japan      1.0
# Toronto        NaN       NaN     Canada      0.0
# Barcelona      NaN       NaN      Spain      0.0

# %%
cities = pd.concat([all_city, city_countries], axis=1, join='inner')
cities
# Out:
#          revenue  employee    country  capital
# Bali      4578.0      50.0  Indonesia        0
# Jakarta   3500.0     100.0  Indonesia        1

# %%
cities = pd.concat([all_city, city_countries], axis=1, join='outer')
cities
# Out:
#            revenue  employee    country  capital
# Bali        4578.0      50.0  Indonesia      0.0
# Jakarta     3500.0     100.0  Indonesia      1.0
# Palembang      NaN      22.0        NaN      NaN
# Riau        9832.0       NaN        NaN      NaN
# Kediri      6547.0      14.0        NaN      NaN
# Sumba        486.0       5.0        NaN      NaN
# Tokyo          NaN       NaN      Japan      1.0
# Toronto        NaN       NaN     Canada      0.0
# Barcelona      NaN       NaN      Spain      0.0

# %% [markdown]
# ## Visualizing data in Pandas with Matplotlib

# %%
# %matplotlib inline
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68    1300.00
# 1            0     NYK   Knicks  ...     TRH   Huskies       66    1300.00
# 2            0     CHS    Stags  ...     NYK    Knicks       47    1306.72
# 3            0     NYK   Knicks  ...     CHS     Stags       63    1300.00
# 4            0     DTF  Falcons  ...     WSC  Capitols       50    1300.00
#
#   opp_elo_n game_location  game_result  forecast  notes difference
# ...

# %%
nba[nba['team_id']=='MNL'].groupby('year_id')['pts'].sum()
# Out:
# year_id
# 1949    5845
# 1950    6809
# 1951    6187
# 1952    6718
# 1953    6968
# 1954    6924
# 1955    7549
# 1956    7614
# 1957    8063
# 1958    7566
# 1959    9004
# 1960    8982
# Name: pts, dtype: int64

# %%
nba[nba['team_id']=='MNL'].groupby('year_id')['pts'].sum().plot()

# %%
nba[nba['team_id']=='MNL'].groupby('year_id')['pts'].sum().plot(kind="bar")
